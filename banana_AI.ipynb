# %% [markdown]
# <a href="https://colab.research.google.com/github/Heartese/AI1/blob/main/banana_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install YOLOv8 (Ultralytics)
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 24.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 117.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 72.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 19.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 43.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# Replace this with your Roboflow download link
# !curl -L "https://app.roboflow.com/ds/KvJ3htXUC3?key=LqsHOyTYoW" > dataset.zip
# !unzip dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/labels/musa-acuminata-rotten-b0b8fdd8-1d0a-11ec-a884-d8c4975e38aa_jpg.rf.5d0f78d064341d9ac90dd9b3bab7743f.txt
#   inflating: train/labels/musa-acuminata-rotten-b0b8fdd8-1d0a-11ec-a884-d8c4975e38aa_jpg.rf.b8831eaf13d93f1764b2a78a70823f23.txt
#   inflating: train/labels/musa-acuminata-rotten-b0b8fdd8-1d0a-11ec-a884-d8c4975e38aa_jpg.rf.e6a081d396e69ff4d6f65690f6b4e999.txt
#   inflating: train/labels/musa-acuminata-rotten-b0bdc348-1d0a-11ec-a245-d8c4975e38aa_jpg.rf.230ca2b6faadc3609ed14e483f0acc58.txt
#   inflating: train/labels/musa-acuminata-rotten-b0bdc348-1d0a-11ec-a245-d8c4975e38aa_jpg.rf.5f6be6e7427c52b3494b3457ffdc9278.txt
#   inflating: train/labels/musa-acuminata-rotten-b0bdc348-1d0a-11ec-a245-d8c4975e38aa_jpg.rf.63d3fb7ef5885b77fa190200ae7958cb.txt
#   inflating: train/labels/musa-acuminata-rotten-b0c28581-1d0a-11ec-b9b5-d8c4975e38aa_jpg.rf.3171df113d9dcb950e48bf5e04c0fca4.txt
# ...

# %%
# !ls
# Out:
# dataset.zip  README.dataset.txt   runs	       test   valid
# data.yaml    README.roboflow.txt  sample_data  train  yolov8n.pt

# %%
from ultralytics import YOLO

# Load a YOLOv8 model (you can use yolov8n.pt, yolov8s.pt, yolov8m.pt, etc.)
model = YOLO("yolov8n.pt")  # 'n' is the smallest, fastest version

# Train the model
model.train(
    data="data.yaml",  # Replace with your correct .yaml path
    epochs=30,
    imgsz=640,
    batch=16
)
# Out:
# Ultralytics 8.3.130 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# Resume from last checkpoint
model.train(resume=True)
